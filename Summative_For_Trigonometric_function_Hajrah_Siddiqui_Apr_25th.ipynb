# %%
#importing libraries
import pandas as pd  #Library for csv
import matplotlib.pyplot as plt #import library for plotting graphs
import numpy as np #numpy
import matplotlib.ticker as tck
import plotly.graph_objects as go

while True:
  #all comments will also be pyt in the "read me section" of the github - this is just reference to me right now
  #do abitious question and the pie axis tomorrow
  #asking what function graph they want to display - first part of assaignment
  #label the coordinates using grid

  question = input("What graph would you like to be displayed on the graph: (cos, sin, or tan)")

  if question == "cos":
    # x_axis = np.arange(0, 6 * np.pi, 0.1) #the np. arrange is basically just essentially np. array which is litterly just making evenly spaces between the x-axis points
                                            # essentially what this is is making evenly spaced out spaces so that my sin graph will come out even when being plot

                                            #the reason I do 6 is because basically its when the sine function stops so when it is reaching 6 * pi it stops
                                            #i can do any number I like but 6 is fine too

                                            #the 0.1 represents how it goes on a step of 0.1 everytime it moves, basically everytime it is plotted
                                            #this can also be changed

                                            #https://pythonforundergradengineers.com/plotting-sin-cos-with-matplotlib.html I got my logic from here =

      #these comments logics all will be replicated in the ambitious question I will do after I plot this

      #https://stackoverflow.com/questions/40642061/how-to-set-axis-ticks-in-multiples-of-pi-python-matplotlib
      # THIS IS FOR THE PIE AXIS

      #Line below I used from them
    # f, ax = plt.subplots(figsize = (10,5))  #will explain all of this in readme function

      #This one I already knew how to do these two ones because I did them above as u can see but instead I  also included...
      # I did -5 * np.pi because what was different from the first one and this one starts at -5, that one started at 0
    # x_axis = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
      #y_axis = np.cos(x_axis)
      #ax.plot(x_axis / np.pi, y_axis)
      #ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
      #ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))



      #plt.style.use("ggplot")
      #plt.title("Sine Function")
      #plt.xlabel("X axis")
      #plt.ylabel("Y axis")
      #plt.show()

      questionForWtvGraph1 = input("Would you like to import your own equation or see the cos function itself? (equation or itself): ")

      if questionForWtvGraph1 == "equation":
      #sin function equation - using that as refrence to plot it
        A_value1 = float(input("Enter your A value, your amplitude: "))
        B_value1 = float(input("Enter your B value, your frequency: "))
        C_value1 = float(input("Enter your C value, your horizontal shift: "))
        D_value1 = float(input("Enter your D value, your vertical shift: "))
        range_Start_Value1 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
        range_Stop_Value1 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

        #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
        sample_rate1 = 1000
        x_axis1 = np.arange(range_Start_Value1, range_Stop_Value1, 1/sample_rate1)
        print(x_axis1)
        CosineWave1 = A_value1 * np.cos(2 * np.pi * B_value1 * x_axis1 + D_value1)
        print(CosineWave1)
        fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
        fig.add_scatter(x=x_axis1, y=CosineWave1)
        fig.show()

      if questionForWtvGraph1 == "itself":
        f, ax = plt.subplots(figsize = (10,5))
        x_axis2 = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
        y_axis2 = np.cos(x_axis2)

        ax.plot(x_axis2 / np.pi, y_axis2)

        ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
        ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))
        plt.style.use("ggplot")
        plt.title("Cosine Function")
        plt.xlabel("X axis")
        plt.ylabel("Y axis")
        plt.show()

      if questionForWtvGraph1 != "itself" and "equation":
          tryAgain1 = input("Inavlid Input. Please ReEnter again: ")
          if tryAgain1 != "itself" and "equation":
            response1 = input(print("Invalid response. Please enter itself or equation"))
            if response1 != "itself" and "equation":
              print("Thanks bye.")
            break


  elif question == "sin": #basically copy of plotting the sin but instead we do cos function

      questionForWtvGraph2 = input("Would you like to import your own equation or see the cos function itself? (equation or itself): ")

      if questionForWtvGraph2 == "equation":
      #sin function equation - using that as refrence to plot it
        A_value2 = float(input("Enter your A value, your amplitude: "))
        B_value2 = float(input("Enter your B value, your frequency: "))
        C_value2 = float(input("Enter your C value, your horizontal shift: "))
        D_value2 = float(input("Enter your D value, your vertical shift: "))
        range_Start_Value2 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
        range_Stop_Value2 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

        #Line below I used from them
        #f, ax = plt.subplots(figsize = (10,5))  #will explain all of this in readme function

        #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
        sample_rate2 = 1000
        x_axis_forSin = np.arange(range_Start_Value2, range_Stop_Value2, 1/sample_rate2)
        print(x_axis_forSin)
        sinewave2 = A_value2 * np.sin(2 * np.pi * B_value2 * x_axis_forSin + D_value2)
        print(sinewave2)
        fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
        fig.add_scatter(x=x_axis_forSin, y=sinewave2)
        fig.show()

    #   x_axis = np.linspace(range_Start_Value * np.pi, range_Stop_Value * np. pi, 1001)

      #  sample_rate = 1000
      # Values = np.arange(range_Start_Value, range_Stop_Value, 1000/sample_rate)
        #print(sample_rate)

        #mathPortion = A_value * np.sin(((B_value * Values) + C_value) + D_value)
        #print(mathPortion)

        #fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
        #plt.plot(Values, mathPortion)
        #plt.show()

        #ax.plot(x / np.pi, y)
        #ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
        #ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))

        #plt.style.use("ggplot")

        #plt.plot(x, y)
        #plt.xlabel("X axis")
        #plt.ylabel("Y axis")
        #plt.show()

      if questionForWtvGraph2 == "itself":
        f, ax = plt.subplots(figsize = (10,5))
        x_axis4 = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
        y_axis4 = np.sin(x_axis4)

        ax.plot(x_axis4 / np.pi, y_axis4)

        ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
        ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))
        plt.style.use("ggplot")
        plt.title("Sine Function")
        plt.xlabel("X axis")
        plt.ylabel("Y axis")
        plt.show()

      if questionForWtvGraph2 != "itself" and "equation":
          tryAgain2 = input("Inavlid Input. Please ReEnter again: ")
          if tryAgain2 != "itself" and "equation":
            response2 = input(print("Invalid response. Please enter itself or equation"))
            if response2 != "itself" and "equation":
              print("Thanks bye.")
            break

      # x_axis2 = np.arange(0, 6 * np.pi, 0.1)
        #y_axis2 = np.cos(x_axis2) #cos function already builts into np
        #plt.plot (x_axis2, y_axis2)
        #plt.grid(True)
        #plt.title("Cosine Function")
        #plt.xlabel("X axis")
        #plt.ylabel("Y axis")
        #plt.show()

      #make it bulletproof

  elif question == "tan":  #https://www.physicsforums.com/threads/graph-tan-and-arctan-with-python.986828/#:~:text=How%20do%20I%20plot%20a,the%20colors%20and%20line%20styles.

     questionForWtvGraph3 = input("Would you like to import your own equation or see the tan function itself? (equation or itself): ")

     if questionForWtvGraph3 == "equation":
      #sin function equation - using that as refrence to plot it
        A_value3 = float(input("Enter your A value, your amplitude: "))
        B_value3 = float(input("Enter your B value, your frequency: "))
        C_value3 = float(input("Enter your C value, your horizontal shift: "))
        D_value3 = float(input("Enter your D value, your vertical shift: "))
        range_Start_Value3 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
        range_Stop_Value3 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

        #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
        sample_rate3 = 1000
        x_axis_fortan = np.arange(range_Start_Value3, range_Stop_Value3, 1/sample_rate3)
        print(x_axis_fortan)
        tanwave3 = A_value3 * np.tan(2 * np.pi * B_value3 * x_axis_fortan + D_value3)
        print(tanwave3)
        fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
        fig.add_scatter(x=x_axis_fortan, y=tanwave3)
        fig.show()

     if questionForWtvGraph3 == "itself":
        f, ax = plt.subplots(figsize = (6, 5))
        x_axis3 = np.linspace(-20 * np.pi, 20 * np. pi, 1001) #I have to do 1000 because I need it to be placed at a circular quadratic motion in order for the pie axis
        y_axis3 = np.tan(x_axis3)

        ax.plot(x_axis3 / np.pi, y_axis3)

        ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
        ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))
        plt.style.use("ggplot")
        plt.title("Tan Function")
        plt.xlabel("X axis")
        plt.ylabel("Y axis")
        plt.show()

     if questionForWtvGraph3 != "itself" or "equation":
          tryAgain3 = input("Inavlid Input. Please ReEnter again: ")
          if tryAgain3 != "itself" or "equation":
            response3 = input(print("Invalid response. Please enter itself or equation"))
            if response3 != "itself" or "equation":
              print("Thanks bye.")
            break
  else:
      print("Invalid Input.")
# Out:
# What graph would you like to be displayed on the graph: (cos, sin, or tan)cos
# Would you like to import your own equation or see the cos function itself? (equation or itself): equation
# Enter your A value, your amplitude: 1
# Enter your B value, your frequency: 1
# Enter your C value, your horizontal shift: 1
# Enter your D value, your vertical shift: 1
# Enter what number you would like for your graph to start at (starting at this point)3
# Enter what number you would like to go up till on your graph: (stopping at that point) 9
# [3.    3.001 3.002 ... 8.997 8.998 8.999]
# [0.54030231 0.53500456 0.52968569 ... 0.55606674 0.5508336  0.54557872]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-9f1020bdb992> in <cell line: 8>()
#      67         CosineWave1 = A_value1 * np.cos(2 * np.pi * B_value1 * x_axis1 + D_value1)
#      68         print(CosineWave1)
# ---> 69         fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis'),title=dict(title='Cosine Graph')))
#      70         fig.add_scatter(x=x_axis1, y=CosineWave1)
#      71         fig.show()
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     627             is invalid AND skip_invalid is False
#     628         """
# --> 629         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     630
#     631     def update(self, dict1=None, overwrite=False, **kwargs) -> "Figure":
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     555
#     556         # ### Import Layout ###
# --> 557         self._layout_obj = self._layout_validator.validate_coerce(
#     558             layout, skip_invalid=skip_invalid, _validate=self._validate
#     559         )
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2473
#    2474         elif isinstance(v, dict):
# -> 2475             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2476
#    2477         elif isinstance(v, self.data_class):
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/_layout.py in __init__(self, arg, activeselection, activeshape, annotations, annotationdefaults, autosize, autotypenumbers, bargap, bargroupgap, barmode, barnorm, boxgap, boxgroupgap, boxmode, calendar, clickmode, coloraxis, colorscale, colorway, computed, datarevision, dragmode, editrevision, extendfunnelareacolors, extendiciclecolors, extendpiecolors, extendsunburstcolors, extendtreemapcolors, font, funnelareacolorway, funnelgap, funnelgroupgap, funnelmode, geo, grid, height, hiddenlabels, hiddenlabelssrc, hidesources, hoverdistance, hoverlabel, hovermode, iciclecolorway, images, imagedefaults, legend, mapbox, margin, meta, metasrc, minreducedheight, minreducedwidth, modebar, newselection, newshape, paper_bgcolor, piecolorway, plot_bgcolor, polar, scattergap, scattermode, scene, selectdirection, selectionrevision, selections, selectiondefaults, separators, shapes, shapedefaults, showlegend, sliders, sliderdefaults, smith, spikedistance, sunburstcolorway, template, ternary, title, titlefont, transition, treemapcolorway, uirevision, uniformtext, updatemenus, updatemenudefaults, violingap, violingroupgap, violinmode, waterfallgap, waterfallgroupgap, waterfallmode, width, xaxis, yaxis, **kwargs)
#    6748         _v = title if title is not None else _v
#    6749         if _v is not None:
# -> 6750             self["title"] = _v
#    6751         _v = arg.pop("titlefont", None)
#    6752         _v = titlefont if titlefont is not None else _v
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    5873         if match is None:
#    5874             # Set as ordinary property
# -> 5875             super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5876         else:
#    5877             # Set as subplotid property
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4863                 # ### Handle compound property ###
#    4864                 if isinstance(validator, CompoundValidator):
# -> 4865                     self._set_compound_prop(prop, value)
#    4866
#    4867                 # ### Handle compound array property ###
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in _set_compound_prop(self, prop, val)
#    5274         # ------------
#    5275         validator = self._get_validator(prop)
# -> 5276         val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5277
#    5278         # Save deep copies of current and new states
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2506         if isinstance(v, (str, int, float)):
#    2507             v = {"text": v}
# -> 2508         return super(TitleValidator, self).validate_coerce(v, skip_invalid=skip_invalid)
#    2509
#    2510
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2473
#    2474         elif isinstance(v, dict):
# -> 2475             v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2476
#    2477         elif isinstance(v, self.data_class):
#
# /usr/local/lib/python3.10/dist-packages/plotly/graph_objs/layout/_title.py in __init__(self, arg, automargin, font, pad, text, x, xanchor, xref, y, yanchor, yref, **kwargs)
#     534         # Process unknown kwargs
#     535         # ----------------------
# --> 536         self._process_kwargs(**dict(arg, **kwargs))
#     537
#     538         # Reset skip_invalid
#
# /usr/local/lib/python3.10/dist-packages/plotly/basedatatypes.py in _process_kwargs(self, **kwargs)
#    4389                 self[k] = v
#    4390             elif not self._skip_invalid:
# -> 4391                 raise err
#    4392         # No need to call _raise_on_invalid_property_error here,
#    4393         # because we have it set up so that the singular case of calling
#
# ValueError: Invalid property specified for object of type plotly.graph_objs.layout.Title: 'title'
#
# Did you mean "text"?
#
#     Valid properties:
#         automargin
#             Determines whether the title can automatically push the
#             figure margins. If `yref='paper'` then the margin will
#             expand to ensure that the title doesn’t overlap with
#             the edges of the container. If `yref='container'` then
#             the margins will ensure that the title doesn’t overlap
#             with the plot area, tick labels, and axis titles. If
#             `automargin=true` and the margins need to be expanded,
#             then y will be set to a default 1 and yanchor will be
#             set to an appropriate default to ensure that minimal
#             margin space is needed. Note that when `yref='paper'`,
#             only 1 or 0 are allowed y values. Invalid values will
#             be reset to the default 1.
#         font
#             Sets the title font. Note that the title's font used to
#             be customized by the now deprecated `titlefont`
#             attribute.
#         pad
#             Sets the padding of the title. Each padding value only
#             applies when the corresponding `xanchor`/`yanchor`
#             value is set accordingly. E.g. for left padding to take
#             effect, `xanchor` must be set to "left". The same rule
#             applies if `xanchor`/`yanchor` is determined
#             automatically. Padding is muted if the respective
#             anchor value is "middle*/*center".
#         text
#             Sets the plot's title. Note that before the existence
#             of `title.text`, the title's contents used to be
#             defined as the `title` attribute itself. This behavior
#             has been deprecated.
#         x
#             Sets the x position with respect to `xref` in
#             normalized coordinates from 0 (left) to 1 (right).
#         xanchor
#             Sets the title's horizontal alignment with respect to
#             its x position. "left" means that the title starts at
#             x, "right" means that the title ends at x and "center"
#             means that the title's center is at x. "auto" divides
#             `xref` by three and calculates the `xanchor` value
#             automatically based on the value of `x`.
#         xref
#             Sets the container `x` refers to. "container" spans the
#             entire `width` of the plot. "paper" refers to the width
#             of the plotting area only.
#         y
#             Sets the y position with respect to `yref` in
#             normalized coordinates from 0 (bottom) to 1 (top).
#             "auto" places the baseline of the title onto the
#             vertical center of the top margin.
#         yanchor
#             Sets the title's vertical alignment with respect to its
#             y position. "top" means that the title's cap line is at
#             y, "bottom" means that the title's baseline is at y and
#             "middle" means that the title's midline is at y. "auto"
#             divides `yref` by three and calculates the `yanchor`
#             value automatically based on the value of `y`.
#         yref
#             Sets the container `y` refers to. "container" spans the
#             entire `height` of the plot. "paper" refers to the
#             height of the plotting area only.
#
# Did you mean "text"?
#
# Bad property path:
# title
# ^^^^^
